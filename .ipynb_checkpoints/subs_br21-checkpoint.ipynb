# %%
import soup
import pandas as pd

dfs_final = soup.dfs_final
# Out:
# C:\Users\willi\anaconda3\lib\site-packages\soupsieve\css_parser.py:813: FutureWarning: The pseudo class ':contains' is deprecated, ':-soup-contains' should be used moving forward.
#   warnings.warn(

# %%
# pré-processamento do dataframe

cols = soup.cols
brdf = dfs_final.reset_index(drop=True).rename(**cols)

brdf.loc[:, 'time_casa':'tecnico_fora'] = brdf.loc[:, 'time_casa':'tecnico_fora'].astype('str').replace(['dict_values\(\[\'', "\']\)", "\(\)",], '', regex=True)

brdf.loc[:, 'gols_casa':'gols_fora'] = brdf.loc[:, 'gols_casa':'gols_fora'].astype('str').replace(['dict_values\(\[\'', "\']\)", "\(\)"], '', regex=True).astype('int')

brdf.loc[:, '11_casa':'sub1_casa'] = brdf.loc[:, '11_casa':'sub1_casa'].astype('str').replace(['dict_values\(\[\\[\'', "\']\]\)", "\(\)", "\'"], '', regex=True).astype('str')

try:
    brdf.loc[:, ['sub1_casa_tempo','sub2_casa_tempo', 'sub3_casa_tempo', 
                 'sub4_casa_tempo', 'sub5_casa_tempo', 'sub1_fora_tempo',
                 'sub2_fora_tempo', 'sub3_fora_tempo', 'sub4_fora_tempo', 'sub5_fora_tempo']] = brdf.loc[:, ['sub1_casa_tempo','sub2_casa_tempo', 'sub3_casa_tempo', 
                 'sub4_casa_tempo', 'sub5_casa_tempo', 'sub1_fora_tempo',
                 'sub2_fora_tempo', 'sub3_fora_tempo', 'sub4_fora_tempo', 'sub5_fora_tempo']].astype('str').astype('int')
except AttributeError:
    None
except ValueError:
    None
    
    
brdf.loc[:, ['sub1_casa','sub2_casa', 'sub3_casa', 'sub4_casa', 'sub5_casa',
             'sub1_fora','sub2_fora', 'sub3_fora', 'sub4_fora', 'sub5_fora']] = brdf.loc[:, ['sub1_casa','sub2_casa', 
                                                                                             'sub3_casa', 'sub4_casa', 'sub5_casa', 
                                                                                             'sub1_fora','sub2_fora', 'sub3_fora', 
                                                                                             'sub4_fora', 'sub5_fora']].astype('str').replace(['dict_values\(\[\(',
                                                                                                                                               "\)]\)", "\(\)", "\'"], '', regex=True)
brdf
# Out:
#       time_casa       tecnico_casa      time_fora                tecnico_fora  \
# 0        Cuiabá   Alberto Valentim      Juventude           Marquinhos Santos
# 1         Bahia    Dado Cavalcanti         Santos              Fernando Diniz
# 2           São      Hernán Crespo     Fluminense               Roger Machado
# 3      Atlético               Cuca      Fortaleza          Juan Pablo Vojvoda
# 4         Ceará      Guto Ferreira         Grêmio                 Tiago Nunes
# ..          ...                ...            ...                         ...
# 375      Santos      Fábio Carille         Cuiabá                    Jorginho
# 376         Atl       Marcelo Cabo       Flamengo  Maurício Ferreira De Souza
# 377   Palmeiras      Abel Ferreira          Ceará                 Tiago Nunes
# 378     América  Marquinhos Santos            São                Rogério Ceni
# 379  Bragantino  Maurício Barbieri  Internacional               Diego Aguirre
#
#      gols_casa  gols_fora                                            11_casa  \
# 0            2          2  Walter, Lucas Ramon, Marllon Borges, Anderson ...
# 1            3          0  Mateus Claus, Germán Conti, Rossi, Danielzinho...
# 2            0          0  Tiago Volpi, Igor Vinícius de Souza, Bruno Fab...
# 3            1          2  Éverson, Guga, Júnior Alonso, Hulk, Guilherme ...
# 4            3          2  João Ricardo Riedi, Messias, Gabriel Lacerda, ...
# ..         ...        ...                                                ...
# 375          1          1  João Paulo, Luis Felipe, Sandry, Léo Baptistão...
# 376          2          0  Fernando Miguel, Arnaldo, Lucas Oliveira, Eder...
# 377          1          0  Vinicius Silvestre, García, Kaiky Naves, Fabin...
# 378          2          0  MG, Matheus Cavichioli, Eduardo Gabriel, Zé Ri...
# 379          1          0  Cleiton Schwengber, Leo Ortiz, Jadsom, Artur, ...
#
#                                                11_fora  \
# 0    Marcelo Carné, Michel, Vitor Mendes, Rafael Fo...
# 1    João Paulo, Felipe Jonatan, Pará, Alison, Kaio...
# 2    Marcos Felipe, Samuel Xavier, Luccas Claro, Eg...
# 3    Felipe Alves Raymundo, Guilherme Tinga, Marcel...
# 4    Brenno, Pedro Geromel, Thiago dos Santos, Math...
# ..                                                 ...
# 375  Walter, João Lucas, Marllon Borges, Paulão, Ca...
# 376  Hugo Souza, Léo Pereira, Renê, Lázaro, Robert ...
# 377  João Ricardo Riedi, Igor, Messias, Fernando So...
# 378  Tiago Volpi, Igor Vinícius de Souza, Bruno Fab...
# 379  Marcelo Lomba, Edenílson, Yuri Alberto, Rodrig...
#
#                                             banco_casa  \
# 0    João Carlos, João Lucas, Paulão, José Walber, ...
# 1    Douglas Friedrich, Júnior Dênis, Luiz Otávio, ...
# 2    Lucas Perri, Diego, Joao Rojas, Luciano, Vitor...
# 3    Matheus Mendes, Réver, Dodô, Jair, Eduardo Var...
# 4    Vinícius Machado, André Luiz, Yony González, F...
# ..                                                 ...
# 375  Jandrei, Carlos Sánchez, Mádson, Wagner, Ivone...
# 376  Luan Polli, Wanderson, Jefferson, André Lima, ...
# 377  Mateus Oliveira, Kaique, Lucas Sena, Pedro Bic...
# 378  Banco, Jori, Diego, Anderson Jesus, Alan Rusch...
# 379  Júlio César, Edimar Fraga, Alerrandro, Helio J...
#
#                                             banco_fora  ...  \
# 0    William, Cleberson, Paulo Henrique, Elton, Mat...  ...
# 1    Vladimir, John, Luis Felipe, Mádson, Jonathan ...  ...
# 2    Muriel Becker, Lucca, Wellington Martins, Gans...  ...
# 3    Marcelo Boeck, Carlinhos, Luiz Henrique, Osval...  ...
# 4    Paulo Victor Vidotti, Victor Ferraz, Walter Ka...  ...
# ..                                                 ...  ...
# 375  João Carlos, Lucas Ramon, Anderson Conceição, ...  ...
# 376  Gabriel Batista, Matheus Cunha, Thiago Fernand...  ...
# 377  Richard, William Oliveira, Airton, Gabriel Lac...  ...
# 378  Lucas Perri, Thiago, Vitor Bueno, Luan, Luis M...  ...
# 379  Vitor Hugo, Emerson Júnior, Heitor, Kaique Roc...  ...
#
#                           sub1_fora  sub1_fora_tempo  \
# 0            Chico, Marcos Vinicios               75
# 1           Kaiky, Marcos Guilherme               73
# 2     Caio Paulista, Raúl Bobadilla               73
# 3       Daniel Guedes, Yago Pikachu               45
# 4       Diogo Barbosa, Bruno Cortez               45
# ..                              ...              ...
# 375      Jonathan Cafu, Lucas Ramon               37
# 376  André Inácio, Thiago Fernandes               74
# 377         Fábio Gonçalves, Marlon               45
# 378        Juan Santos, Vitor Bueno               64
# 379         Renzo Saravia, Mauricio               45
#
#                            sub2_fora sub2_fora_tempo  \
# 0             Michel, Paulo Henrique              75
# 1                       Pará, Mádson              73
# 2       Abel Hernández, Kayky Chagas              74
# 3     Wellington Paulista, Romarinho              65
# 4        Leo Augusto, Jhonata Robert              45
# ..                               ...             ...
# 375          Max, Yuri Oliveira Lima              76
# 376           Lázaro, Matheus França              77
# 377             Stiven Mendoza, Rick              69
# 378              Reinaldo, Welington              65
# 379  Rodrigo Dourado, Johnny Cardoso              45
#
#                                    sub3_fora sub3_fora_tempo  \
# 0    Matheus Peixoto, Fernando Pacheco Rivas              88
# 1        Kaio Jorge, Marcos Leonardo Almeida              83
# 2                         Nenê, Juan Cazares              84
# 3                              Robson, David              65
# 4                   Lucas Silva, Jean Pyerre              45
# ..                                       ...             ...
# 375                 João Pedro Pepê, Auremir              89
# 376                      Bruno Viana, Werton              85
# 377                           Igor, Jorginho              76
# 378                        Diego, Marquinhos              65
# 379               Patrick, Gabriel Boschilia              60
#
#                            sub4_fora sub4_fora_tempo  \
# 0                    Capixaba, Elton              89
# 1         Lucas Braga, Ângelo Borges              85
# 2    Gabriel Teixeira, Luiz Henrique              84
# 3                      Felipe, Jussa              83
# 4               Léo Chú, Gui Azevedo              89
# ..                               ...             ...
# 375  Felipe Marques, Lucas Hernández              89
# 376         Vitor Gabriel, Ryan Luka              85
# 377                     Lima, Cléber              84
# 378                  dict_values([])              []
# 379          Gabriel Mercado, Heitor              77
#
#                             sub5_fora sub5_fora_tempo
# 0                     Alyson, Eltinho              89
# 1                     dict_values([])              []
# 2            Yago, Wellington Martins              88
# 3           Lucas Crispim, Bruno Melo              87
# 4                     dict_values([])              []
# ..                                ...             ...
# 375  Élton Rodrigues Brandão, Jenison              89
# 376                   dict_values([])              []
# 377                   dict_values([])              []
# 378                   dict_values([])              []
# 379              Moisés, Paulo Victor              82
#
# [380 rows x 30 columns]

# %%
# brdf = brdf.astype({'time_casa': 'str', 'tecnico_casa': 'str', 'time_fora': 'str', 'tecnico_fora': 'str', 'gols_casa': 'str', 'gols_fora': 'str',
#                             '11_casa': 'str', '11_fora': 'str', 'banco_casa': 'str', 'banco_fora': 'str', 'sub1_casa': 'str',
#                             'sub1_casa_tempo': 'int', 'sub2_casa': 'str', 'sub2_casa_tempo': 'int', 'sub3_casa': 'str',
#                             'sub3_casa_tempo': 'int', 'sub4_casa': 'str',
#                             'sub4_casa_tempo': 'int', 'sub5_casa': 'str', 'sub5_casa_tempo': 'int', 'sub1_fora': 'str',
#                             'sub1_fora_tempo': 'int', 'sub2_fora': 'str', 'sub2_fora_tempo': 'int', 'sub3_fora': 'str',
#                             'sub3_fora_tempo': 'int', 'sub4_fora': 'str','sub4_fora_tempo': 'int', 'sub5_fora': 'str', 'sub5_fora_tempo': 'int'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-f84a263dade2> in <module>
# ----> 1 brdf = brdf.astype({'time_casa': 'str', 'tecnico_casa': 'str', 'time_fora': 'str', 'tecnico_fora': 'str', 'gols_casa': 'str', 'gols_fora': 'str',
#       2                             '11_casa': 'str', '11_fora': 'str', 'banco_casa': 'str', 'banco_fora': 'str', 'sub1_casa': 'str',
#       3                             'sub1_casa_tempo': 'int', 'sub2_casa': 'str', 'sub2_casa_tempo': 'int', 'sub3_casa': 'str',
#       4                             'sub3_casa_tempo': 'int', 'sub4_casa': 'str',
#       5                             'sub4_casa_tempo': 'int', 'sub5_casa': 'str', 'sub5_casa_tempo': 'int', 'sub1_fora': 'str',
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5860                 if col_name in dtype:
#    5861                     results.append(
# -> 5862                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5863                     )
#    5864                 else:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1072         # work around NumPy brokenness, #1987
#    1073         if np.issubdtype(dtype.type, np.integer):
# -> 1074             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    1075
#    1076         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: setting an array element with a sequence.
