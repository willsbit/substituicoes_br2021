# %%
import PycharmProjects.substituicoes_br2021.soup as soup
import pandas as pd

# %%
time_casa, tecnico_casa, gols_casa, onze_casa, banco_casa, subs_dict_casa = soup.time_casa, soup.tecnico_casa, soup.gols_casa, soup.onze_casa, soup.banco_casa, soup.subs_dict_casa

# %%
time_fora, tecnico_fora, gols_fora, onze_fora, banco_fora, subs_dict_fora = soup.time_fora, soup.tecnico_fora, soup.gols_fora, soup.onze_fora, soup.banco_fora, soup.subs_dict_fora

# %%
categories = ['Casa', 'Fora']
dcts = [time_casa, tecnico_casa, time_fora, tecnico_fora, gols_casa, gols_fora, onze_casa, onze_fora, banco_casa, banco_fora]

dfs = [
    pd.DataFrame([[k, el, cat] for k, v in dcts.items() for el in v])
    for dcts, cat in zip(dcts, categories)
]

cols = {'columns': {0: 'time_casa', 1: 'tecnico_casa', 2: 'time_fora', 3: 'tecnico_fora', 4: 'gols_casa', 5: 'gols_fora', 6: '11_casa', 7: '11_fora', 8: 'banco_casa', 9: 'banco_fora'}}
pd.concat(dfs).reset_index(drop=False).rename(**cols)
# Out:
#        time_casa tecnico_casa time_fora
# 0      time_casa            C      Casa
# 1      time_casa            u      Casa
# 2      time_casa            i      Casa
# 3      time_casa            a      Casa
# 4      time_casa            b      Casa
# 5      time_casa            á      Casa
# 6   tecnico_casa            T      Fora
# 7   tecnico_casa            é      Fora
# 8   tecnico_casa            c      Fora
# 9   tecnico_casa            n      Fora
# 10  tecnico_casa            i      Fora
# 11  tecnico_casa            c      Fora
# 12  tecnico_casa            o      Fora
# 13  tecnico_casa            :      Fora
# 14  tecnico_casa                   Fora
# 15  tecnico_casa            A      Fora
# 16  tecnico_casa            l      Fora
# 17  tecnico_casa            b      Fora
# 18  tecnico_casa            e      Fora
# 19  tecnico_casa            r      Fora
# 20  tecnico_casa            t      Fora
# 21  tecnico_casa            o      Fora
# 22  tecnico_casa                   Fora
# 23  tecnico_casa            V      Fora
# 24  tecnico_casa            a      Fora
# 25  tecnico_casa            l      Fora
# 26  tecnico_casa            e      Fora
# 27  tecnico_casa            n      Fora
# 28  tecnico_casa            t      Fora
# 29  tecnico_casa            i      Fora
# 30  tecnico_casa            m      Fora
# 31     time_fora            J     asdsa
# 32     time_fora            u     asdsa
# 33     time_fora            v     asdsa
# 34     time_fora            e     asdsa
# 35     time_fora            n     asdsa
# 36     time_fora            t     asdsa
# 37     time_fora            u     asdsa
# 38     time_fora            d     asdsa
# 39     time_fora            e     asdsa
